# %%
''' 
algo_path is the directory path to save the algorithm templates.
algo_template is the directory path where the algorithm templates are currently stored.
algos is a dictionary outlining the algorithms to use, defined in default_algos. If None, the default_algos from finetuning.py will be used.
data_stats_filename is the path to the data stats file, which is generated by DataAnalyzer.
data_src_cfg_name is the path to the data source config YAML file.

algo_path: This is the directory path where the algorithm templates will be saved. It's used when copying the algorithm templates from their current 
location to a new location.

algo_template: This is the directory path where the algorithm templates are currently stored. It's used as the source directory when copying the 
algorithm templates.

In other words, algo_template is the source directory and algo_path is the destination directory. 
They could be the same if you're not moving the templates, but typically they would be different.
'''

# %%
from bundle_generation_script import MyBundleGen

# Initialize MyBundleGen
bundle_gen = MyBundleGen(
    algo_path="/var/data/student_home/lia/phuse_thesis_2024/monai_segmentation/algorithm_templates_lia", 
    algo_template="/var/data/student_home/lia/phuse_thesis_2024/monai_segmentation/algorithm_templates_lia", 
    algos=None, 
    data_stats_filename="path/to/data_stats.json", 
    data_src_cfg_name="path/to/data_source_config.yaml"
)

# Get parsed content for the first algorithm
parsed_content = bundle_gen.algos[0].get_parsed_content()
print(parsed_content)
